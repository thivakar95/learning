# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("mckinsey.csv")

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
temp = df.set_index("country")
temp.head()
# Out:
#              year  population continent  life_exp     gdp_cap
# country
# Afghanistan  1952     8425333      Asia    28.801  779.445314
# Afghanistan  1957     9240934      Asia    30.332  820.853030
# Afghanistan  1962    10267083      Asia    31.997  853.100710
# Afghanistan  1967    11537966      Asia    34.020  836.197138
# Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
temp.iloc[0:5,1:3]
# Out:
#              population continent
# country
# Afghanistan     8425333      Asia
# Afghanistan     9240934      Asia
# Afghanistan    10267083      Asia
# Afghanistan    11537966      Asia
# Afghanistan    13079460      Asia

# %%
temp.loc[0:5,1:3]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19260\377424263.py in <cell line: 1>()
# ----> 1 temp.loc[0:5,1:3]
#
# ~\miniconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1065             if self._is_scalar_access(key):
#    1066                 return self.obj._get_value(*key, takeable=self._takeable)
# -> 1067             return self._getitem_tuple(key)
#    1068         else:
#    1069             # we by definition only have the 0th axis
#
# ~\miniconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1254             return self._multi_take(tup)
#    1255
# -> 1256         return self._getitem_tuple_same_dim(tup)
#    1257
#    1258     def _get_label(self, label, axis: int):
#
# ~\miniconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple_same_dim(self, tup)
# ...

# %%
temp.head(3)
# Out:
#              year  population continent  life_exp     gdp_cap
# country
# Afghanistan  1952     8425333      Asia    28.801  779.445314
# Afghanistan  1957     9240934      Asia    30.332  820.853030
# Afghanistan  1962    10267083      Asia    31.997  853.100710

# %%
temp.loc['Afghanistan']
# Out:
#              year  population continent  life_exp     gdp_cap
# country
# Afghanistan  1952     8425333      Asia    28.801  779.445314
# Afghanistan  1957     9240934      Asia    30.332  820.853030
# Afghanistan  1962    10267083      Asia    31.997  853.100710
# Afghanistan  1967    11537966      Asia    34.020  836.197138
# Afghanistan  1972    13079460      Asia    36.088  739.981106
# Afghanistan  1977    14880372      Asia    38.438  786.113360
# Afghanistan  1982    12881816      Asia    39.854  978.011439
# Afghanistan  1987    13867957      Asia    40.822  852.395945
# Afghanistan  1992    16317921      Asia    41.674  649.341395
# Afghanistan  1997    22227415      Asia    41.763  635.341351
# Afghanistan  2002    25268405      Asia    42.129  726.734055
# Afghanistan  2007    31889923      Asia    43.828  974.580338

# %%
temp
# Out:
#              year  population continent  life_exp     gdp_cap
# country
# Afghanistan  1952     8425333      Asia    28.801  779.445314
# Afghanistan  1957     9240934      Asia    30.332  820.853030
# Afghanistan  1962    10267083      Asia    31.997  853.100710
# Afghanistan  1967    11537966      Asia    34.020  836.197138
# Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...         ...       ...       ...         ...
# Zimbabwe     1987     9216418    Africa    62.351  706.157306
# Zimbabwe     1992    10704340    Africa    60.377  693.420786
# Zimbabwe     1997    11404948    Africa    46.809  792.449960
# Zimbabwe     2002    11926563    Africa    39.989  672.038623
# Zimbabwe     2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 5 columns]

# %%
temp.reset_index(inplace=True)

# %%
temp
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %% [markdown]
# # Add a new row

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
new_row = {'country': 'India', 'year': 2000,'life_exp':37.08,'population':13500000,'gdp_cap':900.23}

# %%
df.append(new_row)
# Out:
# C:\Users\AKASH\AppData\Local\Temp\ipykernel_19260\3544121368.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append(new_row)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19260\3544121368.py in <cell line: 1>()
# ----> 1 df.append(new_row)
#
# ~\miniconda3\lib\site-packages\pandas\core\frame.py in append(self, other, ignore_index, verify_integrity, sort)
#    9766         )
#    9767
# -> 9768         return self._append(other, ignore_index, verify_integrity, sort)
#    9769
#    9770     def _append(
#
# ~\miniconda3\lib\site-packages\pandas\core\frame.py in _append(self, other, ignore_index, verify_integrity, sort)
#    9778             if isinstance(other, dict):
#    9779                 if not ignore_index:
# ...

# %%
df.append(new_row,ignore_index=True)
# Out:
# C:\Users\AKASH\AppData\Local\Temp\ipykernel_19260\2283215411.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append(new_row,ignore_index=True)
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# ...

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
len(df)
# Out:
# 1704

# %%
df.loc[len(df)] = ['India',2000 ,13500000,37.08,"Asia",900.23]

# %%
df
# Out:
#           country  year  population continent life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia   28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia   30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia   31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.02  836.197138
# 4     Afghanistan  1972    13079460      Asia   36.088  739.981106
# ...           ...   ...         ...       ...      ...         ...
# 1700     Zimbabwe  1992    10704340    Africa   60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa   46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa   39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa   43.487  469.709298
# 1704        India  2000    13500000     37.08     Asia  900.230000
#
# [1705 rows x 6 columns]

# %%
df.loc[1] = ['India',"",13500000,37.08,"Asia",900.23]

# %%
df
# Out:
#           country  year  population continent life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia   28.801  779.445314
# 1           India          13500000     37.08     Asia  900.230000
# 2     Afghanistan  1962    10267083      Asia   31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.02  836.197138
# 4     Afghanistan  1972    13079460      Asia   36.088  739.981106
# ...           ...   ...         ...       ...      ...         ...
# 1700     Zimbabwe  1992    10704340    Africa   60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa   46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa   39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa   43.487  469.709298
# 1704        India  2000    13500000     37.08     Asia  900.230000
#
# [1705 rows x 6 columns]

# %%
df.iloc[len(df)] = ['India',2000 ,13500000,37.08,"Asia",900.23]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19260\169341399.py in <cell line: 1>()
# ----> 1 df.iloc[len(df)] = ['India',2000 ,13500000,37.08,"Asia",900.23]
#
# ~\miniconda3\lib\site-packages\pandas\core\indexing.py in __setitem__(self, key, value)
#     813             key = com.apply_if_callable(key, self.obj)
#     814         indexer = self._get_setitem_indexer(key)
# --> 815         self._has_valid_setitem_indexer(key)
#     816
#     817         iloc = self if self.name == "iloc" else self.obj.iloc
#
# ~\miniconda3\lib\site-packages\pandas\core\indexing.py in _has_valid_setitem_indexer(self, indexer)
#    1516             elif is_integer(i):
#    1517                 if i >= len(ax):
# -> 1518                     raise IndexError("iloc cannot enlarge its target object")
#    1519             elif isinstance(i, dict):
# ...

# %%
df.iloc[len(df)-1] = ['India',2000 ,13500000,37.08,"Mahesh",900.23]

# %%
df
# Out:
#           country  year  population continent life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia   28.801  779.445314
# 1           India          13500000     37.08     Asia  900.230000
# 2     Afghanistan  1962    10267083      Asia   31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.02  836.197138
# 4     Afghanistan  1972    13079460      Asia   36.088  739.981106
# ...           ...   ...         ...       ...      ...         ...
# 1700     Zimbabwe  1992    10704340    Africa   60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa   46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa   39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa   43.487  469.709298
# 1704        India  2000    13500000     37.08   Mahesh  900.230000
#
# [1705 rows x 6 columns]

# %%
df.loc[len(df)+1] = ['India',2000 ,13500000,37.08,"yoesh",900.23]

# %%
df
# Out:
#           country  year  population continent life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia   28.801  779.445314
# 1           India          13500000     37.08     Asia  900.230000
# 2     Afghanistan  1962    10267083      Asia   31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.02  836.197138
# 4     Afghanistan  1972    13079460      Asia   36.088  739.981106
# ...           ...   ...         ...       ...      ...         ...
# 1701     Zimbabwe  1997    11404948    Africa   46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa   39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa   43.487  469.709298
# 1704        India  2000    13500000     37.08   Mahesh  900.230000
# 1706        India  2000    13500000     37.08    yoesh  900.230000
#
# [1706 rows x 6 columns]

# %%
loc - update and add
iloc - update

# %%
df.head()
# Out:
#        country  year  population continent life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia   28.801  779.445314
# 1        India          13500000     37.08     Asia  900.230000
# 2  Afghanistan  1962    10267083      Asia   31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.02  836.197138
# 4  Afghanistan  1972    13079460      Asia   36.088  739.981106

# %%
a = df.drop(1)
a.head()
# Out:
#        country  year  population continent life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia   28.801  779.445314
# 2  Afghanistan  1962    10267083      Asia   31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.02  836.197138
# 4  Afghanistan  1972    13079460      Asia   36.088  739.981106
# 5  Afghanistan  1977    14880372      Asia   38.438  786.113360

# %%
a.drop(2)
# Out:
#           country  year  population continent life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia   28.801  779.445314
# 3     Afghanistan  1967    11537966      Asia    34.02  836.197138
# 4     Afghanistan  1972    13079460      Asia   36.088  739.981106
# 5     Afghanistan  1977    14880372      Asia   38.438  786.113360
# 6     Afghanistan  1982    12881816      Asia   39.854  978.011439
# ...           ...   ...         ...       ...      ...         ...
# 1701     Zimbabwe  1997    11404948    Africa   46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa   39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa   43.487  469.709298
# 1704        India  2000    13500000     37.08   Mahesh  900.230000
# 1706        India  2000    13500000     37.08    yoesh  900.230000
#
# [1704 rows x 6 columns]

# %%
a.head(7)
# Out:
#        country  year  population continent life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia   28.801  779.445314
# 2  Afghanistan  1962    10267083      Asia   31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.02  836.197138
# 4  Afghanistan  1972    13079460      Asia   36.088  739.981106
# 5  Afghanistan  1977    14880372      Asia   38.438  786.113360
# 6  Afghanistan  1982    12881816      Asia   39.854  978.011439
# 7  Afghanistan  1987    13867957      Asia   40.822  852.395945

# %%
a.drop([1,2,4])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19260\247407231.py in <cell line: 1>()
# ----> 1 a.drop([1,2,4])
#
# ~\miniconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ~\miniconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5397                 weight  1.0     0.8
#    5398         """
# -> 5399         return super().drop(
#    5400             labels=labels,
#    5401             axis=axis,
#
# ~\miniconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
# ...

# %%
df.loc[len(df.index)] = ['India',2000,13500000,"asia",37.08,900.23] 
df.loc[len(df.index)] = ['Sri Lanka',2022 ,130000000,"asia",80.00,500.00] 
df.loc[len(df.index)] = ['Sri Lanka',2022 ,130000000,"asia",80.00,500.00] 
df.loc[len(df.index)] = ['India',2000 ,13500000,"asia",80.00,900.23] 
df
# Out:
#           country  year  population continent life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia   28.801  779.445314
# 1           India          13500000     37.08     Asia  900.230000
# 2     Afghanistan  1962    10267083      Asia   31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.02  836.197138
# 4     Afghanistan  1972    13079460      Asia   36.088  739.981106
# ...           ...   ...         ...       ...      ...         ...
# 1701     Zimbabwe  1997    11404948    Africa   46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa   39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa   43.487  469.709298
# 1704        India  2000    13500000     37.08   Mahesh  900.230000
# 1706        India  2000    13500000      asia     80.0  900.230000
#
# [1706 rows x 6 columns]

# %%
df1= pd.DataFrame({
    'brand': ['Yum Yum', 'Yum Yum', 'Indomie', 'Indomie', 'Indomie'],
    'style': ['cup', 'cup', 'pack', 'pack', 'pack'],
    'rating': [14, 4, 15, 15, 15]
})

# %%
df1
# Out:
#      brand style  rating
# 0  Yum Yum   cup      14
# 1  Yum Yum   cup       4
# 2  Indomie  pack      15
# 3  Indomie  pack      15
# 4  Indomie  pack      15

# %%
df1.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4     True
# dtype: bool

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1701    False
# 1702    False
# 1703    False
# 1704    False
# 1706    False
# Length: 1706, dtype: bool

# %%
df1
# Out:
#      brand style  rating
# 0  Yum Yum   cup      14
# 1  Yum Yum   cup       4
# 2  Indomie  pack      15
# 3  Indomie  pack      15
# 4  Indomie  pack      15

# %%
df1.drop_duplicates(keep=False)
# Out:
#      brand style  rating
# 0  Yum Yum   cup      14
# 1  Yum Yum   cup       4

# %%
df1
# Out:
#      brand style  rating
# 0  Yum Yum   cup       4
# 1  Yum Yum   cup       4
# 2  Indomie  pack      15
# 3  Indomie  pack      15
# 4  Indomie  pack      15

# %%
df1.drop_duplicates(subset='brand')
# Out:
#      brand style  rating
# 0  Yum Yum   cup       4
# 2  Indomie  pack      15

# %%
df1.drop_duplicates(subset=['brand','style'])
# Out:
#      brand style  rating
# 0  Yum Yum   cup      14
# 2  Indomie  pack      15

# %%
df.head(20)
# Out:
#         country  year  population continent life_exp      gdp_cap
# 0   Afghanistan  1952     8425333      Asia   28.801   779.445314
# 1         India          13500000     37.08     Asia   900.230000
# 2   Afghanistan  1962    10267083      Asia   31.997   853.100710
# 3   Afghanistan  1967    11537966      Asia    34.02   836.197138
# 4   Afghanistan  1972    13079460      Asia   36.088   739.981106
# 5   Afghanistan  1977    14880372      Asia   38.438   786.113360
# 6   Afghanistan  1982    12881816      Asia   39.854   978.011439
# 7   Afghanistan  1987    13867957      Asia   40.822   852.395945
# 8   Afghanistan  1992    16317921      Asia   41.674   649.341395
# 9   Afghanistan  1997    22227415      Asia   41.763   635.341351
# 10  Afghanistan  2002    25268405      Asia   42.129   726.734055
# 11  Afghanistan  2007    31889923      Asia   43.828   974.580338
# 12      Albania  1952     1282697    Europe    55.23  1601.056136
# ...

# %%
df.loc[[0,10,20],[0,1,2]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19260\478169716.py in <cell line: 1>()
# ----> 1 df.loc[[0,10,20],[0,1,2]]
#
# ~\miniconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1065             if self._is_scalar_access(key):
#    1066                 return self.obj._get_value(*key, takeable=self._takeable)
# -> 1067             return self._getitem_tuple(key)
#    1068         else:
#    1069             # we by definition only have the 0th axis
#
# ~\miniconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1252         # ugly hack for GH #836
#    1253         if self._multi_take_opportunity(tup):
# -> 1254             return self._multi_take(tup)
#    1255
#    1256         return self._getitem_tuple_same_dim(tup)
#
# ...

# %%
df.loc[[0,10,20],['country','year','population']]
# Out:
#         country  year  population
# 0   Afghanistan  1952     8425333
# 10  Afghanistan  2002    25268405
# 20      Albania  1992     3326498

# %%
df.head()
# Out:
#        country  year  population continent life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia   28.801  779.445314
# 1        India          13500000     37.08     Asia  900.230000
# 2  Afghanistan  1962    10267083      Asia   31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.02  836.197138
# 4  Afghanistan  1972    13079460      Asia   36.088  739.981106

# %%
df.loc[1:5,'year':'life_exp']
# Out:
#    year  population continent life_exp
# 1          13500000     37.08     Asia
# 2  1962    10267083      Asia   31.997
# 3  1967    11537966      Asia    34.02
# 4  1972    13079460      Asia   36.088
# 5  1977    14880372      Asia   38.438

# %%
df.loc[1:10:2]
# Out:
#        country  year  population continent life_exp     gdp_cap
# 1        India          13500000     37.08     Asia  900.230000
# 3  Afghanistan  1967    11537966      Asia    34.02  836.197138
# 5  Afghanistan  1977    14880372      Asia   38.438  786.113360
# 7  Afghanistan  1987    13867957      Asia   40.822  852.395945
# 9  Afghanistan  1997    22227415      Asia   41.763  635.341351

# %% [markdown]
# # Mathematical

# %%
df = pd.read_csv("mckinsey.csv")

# %%
df['life_exp'].mean()
# Out:
# 59.474439366197174

# %%
df['life_exp'].sum()
# Out:
# 101344.44467999999

# %%
df['life_exp'].count()
# Out:
# 1704

# %%
df['life_exp'].sum()/df['life_exp'].count()
# Out:
# 59.474439366197174

# %% [markdown]
# # Sort

# %%
df.sort_values("life_exp")
# Out:
#                country  year  population continent  life_exp       gdp_cap
# 1292            Rwanda  1992     7290203    Africa    23.599    737.068595
# 0          Afghanistan  1952     8425333      Asia    28.801    779.445314
# 552             Gambia  1952      284320    Africa    30.000    485.230659
# 36              Angola  1952     4232095    Africa    30.015   3520.610273
# 1344      Sierra Leone  1952     2143249    Africa    30.331    879.787736
# ...                ...   ...         ...       ...       ...           ...
# 1487       Switzerland  2007     7554661    Europe    81.701  37506.419070
# 695            Iceland  2007      301931    Europe    81.757  36180.789190
# 802              Japan  2002   127065841      Asia    82.000  28604.591900
# 671   Hong Kong, China  2007     6980412      Asia    82.208  39724.978670
# 803              Japan  2007   127467972      Asia    82.603  31656.068060
#
# [1704 rows x 6 columns]

# %%
df.sort_values("life_exp",ascending=False)
# Out:
#                country  year  population continent  life_exp       gdp_cap
# 803              Japan  2007   127467972      Asia    82.603  31656.068060
# 671   Hong Kong, China  2007     6980412      Asia    82.208  39724.978670
# 802              Japan  2002   127065841      Asia    82.000  28604.591900
# 695            Iceland  2007      301931    Europe    81.757  36180.789190
# 1487       Switzerland  2007     7554661    Europe    81.701  37506.419070
# ...                ...   ...         ...       ...       ...           ...
# 1344      Sierra Leone  1952     2143249    Africa    30.331    879.787736
# 36              Angola  1952     4232095    Africa    30.015   3520.610273
# 552             Gambia  1952      284320    Africa    30.000    485.230659
# 0          Afghanistan  1952     8425333      Asia    28.801    779.445314
# 1292            Rwanda  1992     7290203    Africa    23.599    737.068595
#
# [1704 rows x 6 columns]

# %%
df.sort_values(['year','life_exp'])
# Out:
#                country  year  population continent  life_exp       gdp_cap
# 0          Afghanistan  1952     8425333      Asia    28.801    779.445314
# 552             Gambia  1952      284320    Africa    30.000    485.230659
# 36              Angola  1952     4232095    Africa    30.015   3520.610273
# 1344      Sierra Leone  1952     2143249    Africa    30.331    879.787736
# 1032        Mozambique  1952     6446316    Africa    31.286    468.526038
# ...                ...   ...         ...       ...       ...           ...
# 71           Australia  2007    20434176   Oceania    81.235  34435.367440
# 1487       Switzerland  2007     7554661    Europe    81.701  37506.419070
# 695            Iceland  2007      301931    Europe    81.757  36180.789190
# 671   Hong Kong, China  2007     6980412      Asia    82.208  39724.978670
# 803              Japan  2007   127467972      Asia    82.603  31656.068060
#
# [1704 rows x 6 columns]

# %%
df.sort_values(['year','life_exp'],ascending=[True,False])
# Out:
#            country  year  population continent  life_exp       gdp_cap
# 1140        Norway  1952     3327728    Europe    72.670  10095.421720
# 684        Iceland  1952      147962    Europe    72.490   7267.688428
# 1080   Netherlands  1952    10381988    Europe    72.130   8941.571858
# 1464        Sweden  1952     7124673    Europe    71.860   8527.844662
# 408        Denmark  1952     4334000    Europe    70.780   9692.385245
# ...            ...   ...         ...       ...       ...           ...
# 887        Lesotho  2007     2012649    Africa    42.592   1569.331442
# 1355  Sierra Leone  2007     6144562    Africa    42.568    862.540756
# 1691        Zambia  2007    11746035    Africa    42.384   1271.211593
# 1043    Mozambique  2007    19951656    Africa    42.082    823.685621
# 1463     Swaziland  2007     1133066    Africa    39.613   4513.480643
#
# [1704 rows x 6 columns]

# %% [markdown]
# # Join

# %%
users = pd.DataFrame({"userid":[1, 2, 3], "name":["sharadh", "shahid", "khusalli"]})
users
# Out:
#    userid      name
# 0       1   sharadh
# 1       2    shahid
# 2       3  khusalli

# %%
msgs = pd.DataFrame({"userid":[1, 1, 2, 4], "msg":['hmm', "acha", "theek hai", "nice"]})
msgs
# Out:
#    userid        msg
# 0       1        hmm
# 1       1       acha
# 2       2  theek hai
# 3       4       nice

# %%
pd.concat([users,msgs])
# Out:
#    userid      name        msg
# 0       1   sharadh        NaN
# 1       2    shahid        NaN
# 2       3  khusalli        NaN
# 0       1       NaN        hmm
# 1       1       NaN       acha
# 2       2       NaN  theek hai
# 3       4       NaN       nice

# %%
pd.concat([users,msgs],axis=1)
# Out:
#    userid      name  userid        msg
# 0     1.0   sharadh       1        hmm
# 1     2.0    shahid       1       acha
# 2     3.0  khusalli       2  theek hai
# 3     NaN       NaN       4       nice

# %%
msgs
# Out:
#    userid        msg
# 0       1        hmm
# 1       1       acha
# 2       2  theek hai
# 3       4       nice

# %%
users
# Out:
#    userid      name
# 0       1   sharadh
# 1       2    shahid
# 2       3  khusalli

# %%
users.merge(msgs,on='userid')# inner join
# Out:
#    userid     name        msg
# 0       1  sharadh        hmm
# 1       1  sharadh       acha
# 2       2   shahid  theek hai

# %%
users.merge(msgs,on='userid',how='outer')# outer join
# Out:
#    userid      name        msg
# 0       1   sharadh        hmm
# 1       1   sharadh       acha
# 2       2    shahid  theek hai
# 3       3  khusalli        NaN
# 4       4       NaN       nice

# %%
users.merge(msgs,on='userid',how='left')# left join
# Out:
#    userid      name        msg
# 0       1   sharadh        hmm
# 1       1   sharadh       acha
# 2       2    shahid  theek hai
# 3       3  khusalli        NaN

# %%
users.merge(msgs,on='userid',how='right')# right join
# Out:
#    userid     name        msg
# 0       1  sharadh        hmm
# 1       1  sharadh       acha
# 2       2   shahid  theek hai
# 3       4      NaN       nice

# %%
users
# Out:
#    userid      name
# 0       1   sharadh
# 1       2    shahid
# 2       3  khusalli

# %%
msgs
# Out:
#    userid        msg
# 0       1        hmm
# 1       1       acha
# 2       2  theek hai
# 3       4       nice

# %%
users.rename(columns = {"userid":"id"}, inplace = True)
users
# Out:
#    id      name
# 0   1   sharadh
# 1   2    shahid
# 2   3  khusalli

# %%
users.merge(msgs,left_on='id',right_on='userid')# inner join
# Out:
#    id     name  userid        msg
# 0   1  sharadh       1        hmm
# 1   1  sharadh       1       acha
# 2   2   shahid       2  theek hai

# %% [markdown]
# ##### IMDB

# %%
movies = pd.read_csv('movies.csv',index_col=0)

# %%
movies.head()
# Out:
#       id     budget  popularity     revenue  \
# 0  43597  237000000         150  2787965087
# 1  43598  300000000         139   961000000
# 2  43599  245000000         107   880674609
# 3  43600  250000000         112  1084939099
# 5  43602  258000000         115   890871626
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 5                              Spider-Man 3           5.9        3576
#
#    director_id  year month       day
# 0         4762  2009   Dec  Thursday
# 1         4763  2007   May  Saturday
# 2         4764  2015   Oct    Monday
# 3         4765  2012   Jul    Monday
# 5         4767  2007   May   Tuesday

# %%
movies.shape
# Out:
# (1465, 11)

# %% [markdown]
# # How many Directors are making the movies actually

# %%
directors = pd.read_csv('directors.csv', index_col = 0)
directors.head()
# Out:
#        director_name    id gender
# 0      James Cameron  4762   Male
# 1     Gore Verbinski  4763   Male
# 2         Sam Mendes  4764   Male
# 3  Christopher Nolan  4765   Male
# 4     Andrew Stanton  4766   Male

# %%
directors.shape
# Out:
# (2349, 3)

# %%
movies['director_id'].value_counts()
# Out:
# 4799    26
# 4809    19
# 5087    19
# 5457    18
# 4779    16
#         ..
# 5105     5
# 4849     5
# 5096     5
# 5088     5
# 6204     5
# Name: director_id, Length: 199, dtype: int64

# %%
movies['director_id'].nunique()
# Out:
# 199

# %%
movies['director_id'].isin(directors['id'])
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 5       True
#         ...
# 4736    True
# 4743    True
# 4748    True
# 4749    True
# 4768    True
# Name: director_id, Length: 1465, dtype: bool

# %%
np.all(movies['director_id'].isin(directors['id']))
# Out:
# True

# %%
data = movies.merge(directors,how='left',left_on='director_id',right_on='id')

# %%
data.head(3)
# Out:
#     id_x     budget  popularity     revenue  \
# 0  43597  237000000         150  2787965087
# 1  43598  300000000         139   961000000
# 2  43599  245000000         107   880674609
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
#
#    director_id  year month       day   director_name  id_y gender
# 0         4762  2009   Dec  Thursday   James Cameron  4762   Male
# 1         4763  2007   May  Saturday  Gore Verbinski  4763   Male
# 2         4764  2015   Oct    Monday      Sam Mendes  4764   Male

# %%
data.drop(['director_id','id_y'],axis=1,inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1465 entries, 0 to 1464
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id_x           1465 non-null   int64
#  1   budget         1465 non-null   int64
#  2   popularity     1465 non-null   int64
#  3   revenue        1465 non-null   int64
#  4   title          1465 non-null   object
#  5   vote_average   1465 non-null   float64
#  6   vote_count     1465 non-null   int64
#  7   year           1465 non-null   int64
#  8   month          1465 non-null   object
#  9   day            1465 non-null   object
#  10  director_name  1465 non-null   object
#  11  gender         1341 non-null   object
# dtypes: float64(1), int64(6), object(5)
# memory usage: 148.8+ KB

# %%
data.describe()
# Out:
#                id_x        budget   popularity       revenue  vote_average  \
# count   1465.000000  1.465000e+03  1465.000000  1.465000e+03   1465.000000
# mean   45225.191126  4.802295e+07    30.855973  1.432539e+08      6.368191
# std     1189.096396  4.935541e+07    34.845214  2.064918e+08      0.818033
# min    43597.000000  0.000000e+00     0.000000  0.000000e+00      3.000000
# 25%    44236.000000  1.400000e+07    11.000000  1.738013e+07      5.900000
# 50%    45022.000000  3.300000e+07    23.000000  7.578164e+07      6.400000
# 75%    45990.000000  6.600000e+07    41.000000  1.792469e+08      6.900000
# max    48395.000000  3.800000e+08   724.000000  2.787965e+09      8.300000
#
#          vote_count         year
# count   1465.000000  1465.000000
# mean    1146.396587  2002.615017
# std     1578.077438     8.680141
# min        1.000000  1976.000000
# 25%      216.000000  1998.000000
# 50%      571.000000  2004.000000
# 75%     1387.000000  2009.000000
# ...

# %%
data.describe(include=object)
# Out:
#          title month     day     director_name gender
# count     1465  1465    1465              1465   1341
# unique    1465    12       7               199      2
# top     Avatar   Dec  Friday  Steven Spielberg   Male
# freq         1   193     654                26   1309

# %%
data.head()
# Out:
#     id_x     budget  popularity     revenue  \
# 0  43597  237000000         150  2787965087
# 1  43598  300000000         139   961000000
# 2  43599  245000000         107   880674609
# 3  43600  250000000         112  1084939099
# 4  43602  258000000         115   890871626
#
#                                       title  vote_average  vote_count  year  \
# 0                                    Avatar           7.2       11800  2009
# 1  Pirates of the Caribbean: At World's End           6.9        4500  2007
# 2                                   Spectre           6.3        4466  2015
# 3                     The Dark Knight Rises           7.6        9106  2012
# 4                              Spider-Man 3           5.9        3576  2007
#
#   month       day      director_name gender
# 0   Dec  Thursday      James Cameron   Male
# 1   May  Saturday     Gore Verbinski   Male
# 2   Oct    Monday         Sam Mendes   Male
# 3   Jul    Monday  Christopher Nolan   Male
# ...

# %%
data['revenue'] = (data['revenue']/1000000).round(2)

# %%
data
# Out:
#        id_x     budget  popularity  revenue  \
# 0     43597  237000000         150  2787.97
# 1     43598  300000000         139   961.00
# 2     43599  245000000         107   880.67
# 3     43600  250000000         112  1084.94
# 4     43602  258000000         115   890.87
# ...     ...        ...         ...      ...
# 1460  48363          0           3     0.32
# 1461  48370      27000          19     3.15
# 1462  48375          0           7     0.00
# 1463  48376          0           3     0.00
# 1464  48395     220000          14     2.04
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# ...

# %%
SELECT * FROM movies WHERE vote_average > 7

# %%
data['vote_average']>7
# Out:
# 0        True
# 1       False
# 2       False
# 3        True
# 4       False
#         ...
# 1460     True
# 1461     True
# 1462    False
# 1463    False
# 1464    False
# Name: vote_average, Length: 1465, dtype: bool

# %%
data[data['vote_average']>7]
# Out:
#        id_x     budget  popularity  revenue  \
# 0     43597  237000000         150  2787.97
# 3     43600  250000000         112  1084.94
# 14    43616  250000000         120   956.02
# 16    43619  250000000          94   958.40
# 19    43622  200000000         100  1845.03
# ...     ...        ...         ...      ...
# 1456  48321      10000          20     7.00
# 1457  48323          0           5     0.00
# 1458  48335      60000          27     3.22
# 1460  48363          0           3     0.32
# 1461  48370      27000          19     3.15
#
#                                           title  vote_average  vote_count  \
# 0                                        Avatar           7.2       11800
# 3                         The Dark Knight Rises           7.6        9106
# 14    The Hobbit: The Battle of the Five Armies           7.1        4760
# 16          The Hobbit: The Desolation of Smaug           7.6        4524
# ...

# %%
data.loc[data['vote_average']>7]
# Out:
#        id_x     budget  popularity  revenue  \
# 0     43597  237000000         150  2787.97
# 3     43600  250000000         112  1084.94
# 14    43616  250000000         120   956.02
# 16    43619  250000000          94   958.40
# 19    43622  200000000         100  1845.03
# ...     ...        ...         ...      ...
# 1456  48321      10000          20     7.00
# 1457  48323          0           5     0.00
# 1458  48335      60000          27     3.22
# 1460  48363          0           3     0.32
# 1461  48370      27000          19     3.15
#
#                                           title  vote_average  vote_count  \
# 0                                        Avatar           7.2       11800
# 3                         The Dark Knight Rises           7.6        9106
# 14    The Hobbit: The Battle of the Five Armies           7.1        4760
# 16          The Hobbit: The Desolation of Smaug           7.6        4524
# ...

# %%
data.iloc[data['vote_average']>7]
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19260\3158225060.py in <cell line: 1>()
# ----> 1 data.iloc[data['vote_average']>7]
#
# ~\miniconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1071
#    1072             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1073             return self._getitem_axis(maybe_callable, axis=axis)
#    1074
#    1075     def _is_scalar_access(self, key: tuple):
#
# ~\miniconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1609
#    1610         if com.is_bool_indexer(key):
# -> 1611             self._validate_key(key, axis)
#    1612             return self._getbool_axis(key, axis=axis)
#    1613
#
# ~\miniconda3\lib\site-packages\pandas\core\indexing.py in _validate_key(self, key, axis)
# ...

# %%
data.loc[data['vote_average']>7,['title','director_name']]
# Out:
#                                           title      director_name
# 0                                        Avatar      James Cameron
# 3                         The Dark Knight Rises  Christopher Nolan
# 14    The Hobbit: The Battle of the Five Armies      Peter Jackson
# 16          The Hobbit: The Desolation of Smaug      Peter Jackson
# 19                                      Titanic      James Cameron
# ...                                         ...                ...
# 1456                                 Eraserhead        David Lynch
# 1457                                 The Mighty      Peter Chelsom
# 1458                                         Pi   Darren Aronofsky
# 1460                             The Last Waltz    Martin Scorsese
# 1461                                     Clerks        Kevin Smith
#
# [301 rows x 2 columns]

# %%
fil1 = (data['vote_average'] > 7)
fil2 = (data['year']>=2015)
data.loc[fil1  & fil2 ]
# Out:
#        id_x     budget  popularity  revenue                    title  \
# 30    43641  190000000         102  1506.25                Furious 7
# 78    43724  150000000         434   378.86       Mad Max: Fury Road
# 106   43773  135000000         100   532.95             The Revenant
# 162   43867  108000000         167   630.16              The Martian
# 312   44128   75000000          48   108.15  The Man from U.N.C.L.E.
# 394   44281   44000000          68   155.76        The Hateful Eight
# 625   44770   35000000          53   194.56               The Intern
# 635   44784   40000000          48   165.48          Bridge of Spies
# 808   45194   30000000          65    91.71                 Southpaw
# 833   45293   28000000          61   201.63   Straight Outta Compton
# 839   45301   28000000          57   133.35            The Big Short
# 1344  47181    5000000          22    24.80                     Race
#
#       vote_average  vote_count  year month        day  \
# ...

# %%
#Explain real words
#How to drop the whole df?
not understood id_x why created

# %%
When we create explicit index, it also assigns column names automatically?

# %%
del df

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19260\1396537375.py in <cell line: 1>()
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
ll = [['Afghanistan',1952, 8425333, 'Asia', 28.801, 779.445314 ],
['Afghanistan',1957, 9240934, 'Asia', 30.332, 820.853030 ],
['Afghanistan',1962, 102267083, 'Asia', 31.997, 853.100710 ]]
d = pd.DataFrame(ll,columns=['country','year','population','continent','life_exp','gdp_cap'])

# %%
d
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962   102267083      Asia    31.997  853.100710

# %%
d.index = ['a','b','c']

# %%
d
# Out:
#        country  year  population continent  life_exp     gdp_cap
# a  Afghanistan  1952     8425333      Asia    28.801  779.445314
# b  Afghanistan  1957     9240934      Asia    30.332  820.853030
# c  Afghanistan  1962   102267083      Asia    31.997  853.100710

# %% [markdown]
# # More Hands on
# # Cheatsheet
