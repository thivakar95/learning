# %%
print(7412)
# Out:
# 7412

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Quiz 1**

# %%
Quiz 1

print(10)

A. 10

B. "10"

C. Ten

D. Error

# %%
print(10)
#Ans A
# Out:
# 10

# %%
print(30+20)
# Out:
# 50

# %%
#esc+b

# %% [markdown]
# Quiz 2

# %%
print (  4 +            9   ) #spaces in middle doesn't matter
# Out:
# 13

# %%
print(8-5)
A. 8-5

B. 3

C. Error

# %%
print(8-5)
# Out:
# 3

# %%
print(4*9)
A. 4*9

B. 36

C. Error

# %%
print(4*9)
# Out:
# 36

# %% [markdown]
# ## **Quiz 4**
#
#
# 1.   Predict the output of the following
#     ```python
#     print("10")
#     ```
#     A. 10
#
#     B. "10"
#
#     C. Ten
#
#     D. Error

# %%
print("10")
# Out:
# 10

# %%
print("AKASH")
# Out:
# AKASH

# %%
# everything inside " " printed as such
print("I love you all 3000!!!")
# Out:
# I love you all 3000!!!

# %%
# can be seen that it need double quotes
print(I love you all 3000!)
# Out:
#   File "<ipython-input-14-c0dd151c2039>", line 2
#     print(I love you all 3000!)
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
print("Hello"
# Out:
#   File "<ipython-input-15-73b2b6fc1c24>", line 1
#     print("Hello"
#                  ^
# SyntaxError: incomplete input

# %% [markdown]
# ## **Quiz 5**
#
#
# 1.   Predict the output of the following
#     ```python
#     Print("5+10")
#     ```
#     A. 5+10
#
#     B. 15
#
#     C. Error

# %%
Print("5+10")#case sensitive
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-f3c1e93090d1> in <cell line: 1>()
# ----> 1 Print("5+10")
#
# NameError: name 'Print' is not defined

# %%
print("5+10")#case sensitive
# Out:
# 5+10

# %% [markdown]
# ## **Quiz 6**
#
#
# 1.   Predict the output of the following
#     ```python
#     print("10+10")
#     ```
#     A. 20
#
#     B. "10+10"
#
#     C. 10+10
#
#     D. Error

# %%
print("10+10")
# Out:
# 10+10

# %%
-
-
-
-
-
-
-
-
