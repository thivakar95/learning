# %%
import pandas as pd
import numpy as np

# !gdown 1s2TkjSpzNc4SyxqRrQleZyDIHlc7bxnd
# !gdown 1Ws-_s1fHZ9nHfGLVUQurbHDvStePlEJm

movies = pd.read_csv('movies.csv', index_col=0)
directors = pd.read_csv('directors.csv',index_col=0)

data = movies.merge(directors, how='left', left_on='director_id',right_on='id')
data.drop(['director_id','id_y'],axis=1,inplace=True)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1s2TkjSpzNc4SyxqRrQleZyDIHlc7bxnd
# To: /home/thivakaranb/Pictures/DS_learning/Module4/Pandas4/movies.csv
# 100%|████████████████████████████████████████| 112k/112k [00:00<00:00, 1.17MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1Ws-_s1fHZ9nHfGLVUQurbHDvStePlEJm
# To: /home/thivakaranb/Pictures/DS_learning/Module4/Pandas4/directors.csv
# 100%|███████████████████████████████████████| 65.4k/65.4k [00:00<00:00, 514kB/s]

# %%
data.head()
# Out:
#     id_x     budget  popularity     revenue  \
# 0  43597  237000000         150  2787965087
# 1  43598  300000000         139   961000000
# 2  43599  245000000         107   880674609
# 3  43600  250000000         112  1084939099
# 4  43602  258000000         115   890871626
#
#                                       title  vote_average  vote_count  year  \
# 0                                    Avatar           7.2       11800  2009
# 1  Pirates of the Caribbean: At World's End           6.9        4500  2007
# 2                                   Spectre           6.3        4466  2015
# 3                     The Dark Knight Rises           7.6        9106  2012
# 4                              Spider-Man 3           5.9        3576  2007
#
#   month       day      director_name gender
# 0   Dec  Thursday      James Cameron   Male
# 1   May  Saturday     Gore Verbinski   Male
# 2   Oct    Monday         Sam Mendes   Male
# 3   Jul    Monday  Christopher Nolan   Male
# ...

# %%
data.groupby('director_name')['title'].count()
# Out:
# director_name
# Adam McKay                      6
# Adam Shankman                   8
# Alejandro González Iñárritu     6
# Alex Proyas                     5
# Alexander Payne                 5
#                                ..
# Wes Craven                     10
# Wolfgang Petersen               7
# Woody Allen                    18
# Zack Snyder                     7
# Zhang Yimou                     6
# Name: title, Length: 199, dtype: int64

# %%
agg_df = data.groupby('director_name')[['year','title']].aggregate({'year':['min','max'],'title':'count'})

# %% [raw]
# agg_df

# %%
agg_df
# Out:
#                              year       title
#                               min   max count
# director_name
# Adam McKay                   2004  2015     6
# Adam Shankman                2001  2012     8
# Alejandro González Iñárritu  2000  2015     6
# Alex Proyas                  1994  2016     5
# Alexander Payne              1999  2013     5
# ...                           ...   ...   ...
# Wes Craven                   1984  2011    10
# Wolfgang Petersen            1981  2006     7
# Woody Allen                  1977  2013    18
# Zack Snyder                  2004  2016     7
# Zhang Yimou                  2002  2014     6
#
# [199 rows x 3 columns]

# %%
agg_df['year']
# Out:
#                               min   max
# director_name
# Adam McKay                   2004  2015
# Adam Shankman                2001  2012
# Alejandro González Iñárritu  2000  2015
# Alex Proyas                  1994  2016
# Alexander Payne              1999  2013
# ...                           ...   ...
# Wes Craven                   1984  2011
# Wolfgang Petersen            1981  2006
# Woody Allen                  1977  2013
# Zack Snyder                  2004  2016
# Zhang Yimou                  2002  2014
#
# [199 rows x 2 columns]

# %%
[i for i in agg_df.columns]
# Out:
# [('year', 'min'), ('year', 'max'), ('title', 'count')]

# %%
["_".join(i) for i in agg_df.columns]
# Out:
# ['year_min', 'year_max', 'title_count']

# %%
"_".join({'a','b'})
# Out:
# 'a_b'

# %%
agg_df.columns = ["_".join(i) for i in agg_df.columns]

# %%
agg_df
# Out:
#                              year_min  year_max  title_count
# director_name
# Adam McKay                       2004      2015            6
# Adam Shankman                    2001      2012            8
# Alejandro González Iñárritu      2000      2015            6
# Alex Proyas                      1994      2016            5
# Alexander Payne                  1999      2013            5
# ...                               ...       ...          ...
# Wes Craven                       1984      2011           10
# Wolfgang Petersen                1981      2006            7
# Woody Allen                      1977      2013           18
# Zack Snyder                      2004      2016            7
# Zhang Yimou                      2002      2014            6
#
# [199 rows x 3 columns]

# %%
agg_df.reset_index()
# Out:
#                    director_name  year_min  year_max  title_count
# 0                     Adam McKay      2004      2015            6
# 1                  Adam Shankman      2001      2012            8
# 2    Alejandro González Iñárritu      2000      2015            6
# 3                    Alex Proyas      1994      2016            5
# 4                Alexander Payne      1999      2013            5
# ..                           ...       ...       ...          ...
# 194                   Wes Craven      1984      2011           10
# 195            Wolfgang Petersen      1981      2006            7
# 196                  Woody Allen      1977      2013           18
# 197                  Zack Snyder      2004      2016            7
# 198                  Zhang Yimou      2002      2014            6
#
# [199 rows x 4 columns]

# %%
#no of active years
agg_df['yr_of_active'] = agg_df['year_max'] - agg_df['year_min']

# %%
agg_df
# Out:
#                              year_min  year_max  title_count  yr_of_active
# director_name
# Adam McKay                       2004      2015            6            11
# Adam Shankman                    2001      2012            8            11
# Alejandro González Iñárritu      2000      2015            6            15
# Alex Proyas                      1994      2016            5            22
# Alexander Payne                  1999      2013            5            14
# ...                               ...       ...          ...           ...
# Wes Craven                       1984      2011           10            27
# Wolfgang Petersen                1981      2006            7            25
# Woody Allen                      1977      2013           18            36
# Zack Snyder                      2004      2016            7            12
# Zhang Yimou                      2002      2014            6            12
#
# [199 rows x 4 columns]

# %%
agg_df.sort_values(['yr_of_active'],ascending=False)
# Out:
#                   year_min  year_max  title_count  yr_of_active
# director_name
# Steven Spielberg      1977      2016           26            39
# Martin Scorsese       1976      2013           19            37
# George Miller         1979      2015            7            36
# Ridley Scott          1979      2015           16            36
# Woody Allen           1977      2013           18            36
# ...                    ...       ...          ...           ...
# Jon M. Chu            2008      2016            5             8
# Jason Reitman         2005      2013            5             8
# Uwe Boll              2005      2013            5             8
# Tyler Perry           2006      2013            9             7
# Jason Friedberg       2006      2010            5             4
#
# [199 rows x 4 columns]

# %% [raw]
# PFIZER data

# %%
# !gdown 173A59xh2mnpmljCCB9bhC4C5eP2IS6qZ
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=173A59xh2mnpmljCCB9bhC4C5eP2IS6qZ
# To: /home/thivakaranb/Pictures/DS_learning/Module4/Pandas4/Pfizer_1.csv
# 100%|██████████████████████████████████████| 1.51k/1.51k [00:00<00:00, 11.0MB/s]

# %%
pfizer_df = pd.read_csv('Pfizer_1.csv')

# %%
pfizer_df
# Out:
#           Date                Drug_Name    Parameter  1:30:00  2:30:00  \
# 0   15-10-2020  diltiazem hydrochloride  Temperature     23.0     22.0
# 1   15-10-2020  diltiazem hydrochloride     Pressure     12.0     13.0
# 2   15-10-2020      docetaxel injection  Temperature      NaN     17.0
# 3   15-10-2020      docetaxel injection     Pressure      NaN     22.0
# 4   15-10-2020   ketamine hydrochloride  Temperature     24.0      NaN
# 5   15-10-2020   ketamine hydrochloride     Pressure      8.0      NaN
# 6   16-10-2020  diltiazem hydrochloride  Temperature     34.0     35.0
# 7   16-10-2020  diltiazem hydrochloride     Pressure     18.0     19.0
# 8   16-10-2020      docetaxel injection  Temperature     46.0     47.0
# 9   16-10-2020      docetaxel injection     Pressure     23.0     24.0
# 10  16-10-2020   ketamine hydrochloride  Temperature      8.0      9.0
# 11  16-10-2020   ketamine hydrochloride     Pressure     12.0     12.0
# ...

# %%
pd.melt(agg_df,id_vars=['yr_of_active','director_name'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 pd.melt(agg_df,id_vars=['yr_of_active','director_name'])
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/reshape/melt.py:69, in melt(frame, id_vars, value_vars, var_name, value_name, col_level, ignore_index)
#      67         missing = Index(com.flatten(id_vars)).difference(cols)
#      68         if not missing.empty:
# ---> 69             raise KeyError(
#      70                 "The following 'id_vars' are not present "
#      71                 f"in the DataFrame: {list(missing)}"
#      72             )
#      73 else:
#      74     id_vars = []
#
# KeyError: "The following 'id_vars' are not present in the DataFrame: ['director_name']"

# %%
agg_df.head()
# Out:
#                              year_min  year_max  title_count  yr_of_active
# director_name
# Adam McKay                       2004      2015            6            11
# Adam Shankman                    2001      2012            8            11
# Alejandro González Iñárritu      2000      2015            6            15
# Alex Proyas                      1994      2016            5            22
# Alexander Payne                  1999      2013            5            14

# %%
agg_df.reset_index(inplace=True)

# %%
pd.melt(agg_df,id_vars=['yr_of_active','director_name']).sort_values('director_name')
# Out:
#      yr_of_active  director_name     variable  value
# 0              11     Adam McKay     year_min   2004
# 199            11     Adam McKay     year_max   2015
# 398            11     Adam McKay  title_count      6
# 1              11  Adam Shankman     year_min   2001
# 200            11  Adam Shankman     year_max   2012
# ..            ...            ...          ...    ...
# 197            12    Zack Snyder     year_min   2004
# 396            12    Zack Snyder     year_max   2016
# 397            12    Zhang Yimou     year_max   2014
# 198            12    Zhang Yimou     year_min   2002
# 596            12    Zhang Yimou  title_count      6
#
# [597 rows x 4 columns]

# %%
pfizer_df
# Out:
#           Date                Drug_Name    Parameter  1:30:00  2:30:00  \
# 0   15-10-2020  diltiazem hydrochloride  Temperature     23.0     22.0
# 1   15-10-2020  diltiazem hydrochloride     Pressure     12.0     13.0
# 2   15-10-2020      docetaxel injection  Temperature      NaN     17.0
# 3   15-10-2020      docetaxel injection     Pressure      NaN     22.0
# 4   15-10-2020   ketamine hydrochloride  Temperature     24.0      NaN
# 5   15-10-2020   ketamine hydrochloride     Pressure      8.0      NaN
# 6   16-10-2020  diltiazem hydrochloride  Temperature     34.0     35.0
# 7   16-10-2020  diltiazem hydrochloride     Pressure     18.0     19.0
# 8   16-10-2020      docetaxel injection  Temperature     46.0     47.0
# 9   16-10-2020      docetaxel injection     Pressure     23.0     24.0
# 10  16-10-2020   ketamine hydrochloride  Temperature      8.0      9.0
# 11  16-10-2020   ketamine hydrochloride     Pressure     12.0     12.0
# ...

# %%
pd.melt(pfizer_df,id_vars=['Date','Drug_Name','Parameter'],var_name='time',value_name='reading').head()
# Out:
#          Date                Drug_Name    Parameter     time  reading
# 0  15-10-2020  diltiazem hydrochloride  Temperature  1:30:00     23.0
# 1  15-10-2020  diltiazem hydrochloride     Pressure  1:30:00     12.0
# 2  15-10-2020      docetaxel injection  Temperature  1:30:00      NaN
# 3  15-10-2020      docetaxel injection     Pressure  1:30:00      NaN
# 4  15-10-2020   ketamine hydrochloride  Temperature  1:30:00     24.0

# %%
pd.melt(pfizer_df,id_vars=['Date','Drug_Name','Parameter']).head()
# Out:
#          Date                Drug_Name    Parameter variable  value
# 0  15-10-2020  diltiazem hydrochloride  Temperature  1:30:00   23.0
# 1  15-10-2020  diltiazem hydrochloride     Pressure  1:30:00   12.0
# 2  15-10-2020      docetaxel injection  Temperature  1:30:00    NaN
# 3  15-10-2020      docetaxel injection     Pressure  1:30:00    NaN
# 4  15-10-2020   ketamine hydrochloride  Temperature  1:30:00   24.0

# %%
#Pivot reshape 
! gdown https://raw.githubusercontent.com/codebasics/py/master/pandas/10_pivot/weather.csv
! gdown https://raw.githubusercontent.com/codebasics/py/master/pandas/10_pivot/weather2.csv
! gdown https://raw.githubusercontent.com/codebasics/py/master/pandas/10_pivot/weather3.csv
# Out:
# Downloading...
# From: https://raw.githubusercontent.com/codebasics/py/master/pandas/10_pivot/weather.csv
# To: /home/thivakaranb/Pictures/DS_learning/Module4/Pandas4/weather.csv
# 241B [00:00, 2.67MB/s]
# Downloading...
# From: https://raw.githubusercontent.com/codebasics/py/master/pandas/10_pivot/weather2.csv
# To: /home/thivakaranb/Pictures/DS_learning/Module4/Pandas4/weather2.csv
# 215B [00:00, 848kB/s]
# Downloading...
# From: https://raw.githubusercontent.com/codebasics/py/master/pandas/10_pivot/weather3.csv
# To: /home/thivakaranb/Pictures/DS_learning/Module4/Pandas4/weather3.csv
# 178B [00:00, 632kB/s]

# %%
weather_df = pd.read_csv("weather.csv")

# %%
weather_df
# Out:
#        date      city  temperature  humidity
# 0  5/1/2017  new york           65        56
# 1  5/2/2017  new york           66        58
# 2  5/3/2017  new york           68        60
# 3  5/1/2017    mumbai           75        80
# 4  5/2/2017    mumbai           78        83
# 5  5/3/2017    mumbai           82        85
# 6  5/1/2017   beijing           80        26
# 7  5/2/2017   beijing           77        30
# 8  5/3/2017   beijing           79        35

# %%
weather_df.pivot(index='city',columns='date')
# Out:
#          temperature                   humidity
# date        5/1/2017 5/2/2017 5/3/2017 5/1/2017 5/2/2017 5/3/2017
# city
# beijing           80       77       79       26       30       35
# mumbai            75       78       82       80       83       85
# new york          65       66       68       56       58       60

# %%
weather_df.pivot(index='city',columns='date',values='humidity')
# Out:
# date      5/1/2017  5/2/2017  5/3/2017
# city
# beijing         26        30        35
# mumbai          80        83        85
# new york        56        58        60

# %%
weather_df.pivot(index='date',columns='city')
# Out:
#          temperature                 humidity
# city         beijing mumbai new york  beijing mumbai new york
# date
# 5/1/2017          80     75       65       26     80       56
# 5/2/2017          77     78       66       30     83       58
# 5/3/2017          79     82       68       35     85       60

# %%
weather_df.pivot_table(index='date',columns='city')
# Out:
#          humidity                 temperature
# city      beijing mumbai new york     beijing mumbai new york
# date
# 5/1/2017     26.0   80.0     56.0        80.0   75.0     65.0
# 5/2/2017     30.0   83.0     58.0        77.0   78.0     66.0
# 5/3/2017     35.0   85.0     60.0        79.0   82.0     68.0

# %%
weather_df.pivot_table(index='date',columns='city',aggfunc='mean')
# Out:
#          humidity                 temperature
# city      beijing mumbai new york     beijing mumbai new york
# date
# 5/1/2017     26.0   80.0     56.0        80.0   75.0     65.0
# 5/2/2017     30.0   83.0     58.0        77.0   78.0     66.0
# 5/3/2017     35.0   85.0     60.0        79.0   82.0     68.0

# %%
weather_df.pivot_table(index='date',columns='city',aggfunc='sum')
# Out:
#          humidity                 temperature
# city      beijing mumbai new york     beijing mumbai new york
# date
# 5/1/2017       26     80       56          80     75       65
# 5/2/2017       30     83       58          77     78       66
# 5/3/2017       35     85       60          79     82       68

# %%
df = pd.read_csv("weather2.csv")
df
# Out:
#        date      city  temperature  humidity
# 0  5/1/2017  new york           65        56
# 1  5/1/2017  new york           61        54
# 2  5/2/2017  new york           70        60
# 3  5/2/2017  new york           72        62
# 4  5/1/2017    mumbai           75        80
# 5  5/1/2017    mumbai           78        83
# 6  5/2/2017    mumbai           82        85
# 7  5/2/2017    mumbai           80        26

# %%
df.pivot_table(index='city',columns='date',aggfunc='sum')
# Out:
#          humidity          temperature
# date     5/1/2017 5/2/2017    5/1/2017 5/2/2017
# city
# mumbai        163      111         153      162
# new york      110      122         126      142

# %%
df.pivot_table(index='city',columns='date',aggfunc='mean')
# Out:
#          humidity          temperature
# date     5/1/2017 5/2/2017    5/1/2017 5/2/2017
# city
# mumbai       81.5     55.5        76.5     81.0
# new york     55.0     61.0        63.0     71.0

# %%
df.pivot_table(index='city',columns='date')
# Out:
#          humidity          temperature
# date     5/1/2017 5/2/2017    5/1/2017 5/2/2017
# city
# mumbai       81.5     55.5        76.5     81.0
# new york     55.0     61.0        63.0     71.0

# %%
df.pivot_table(index='city',columns='date',aggfunc='min')
# Out:
#          humidity          temperature
# date     5/1/2017 5/2/2017    5/1/2017 5/2/2017
# city
# mumbai         80       26          75       80
# new york       54       60          61       70

# %%
pfizer_df
# Out:
#           Date                Drug_Name    Parameter  1:30:00  2:30:00  \
# 0   15-10-2020  diltiazem hydrochloride  Temperature     23.0     22.0
# 1   15-10-2020  diltiazem hydrochloride     Pressure     12.0     13.0
# 2   15-10-2020      docetaxel injection  Temperature      NaN     17.0
# 3   15-10-2020      docetaxel injection     Pressure      NaN     22.0
# 4   15-10-2020   ketamine hydrochloride  Temperature     24.0      NaN
# 5   15-10-2020   ketamine hydrochloride     Pressure      8.0      NaN
# 6   16-10-2020  diltiazem hydrochloride  Temperature     34.0     35.0
# 7   16-10-2020  diltiazem hydrochloride     Pressure     18.0     19.0
# 8   16-10-2020      docetaxel injection  Temperature     46.0     47.0
# 9   16-10-2020      docetaxel injection     Pressure     23.0     24.0
# 10  16-10-2020   ketamine hydrochloride  Temperature      8.0      9.0
# 11  16-10-2020   ketamine hydrochloride     Pressure     12.0     12.0
# ...

# %%
pfizer_df.isna().head()
# Out:
#     Date  Drug_Name  Parameter  1:30:00  2:30:00  3:30:00  4:30:00  5:30:00  \
# 0  False      False      False    False    False     True    False    False
# 1  False      False      False    False    False     True    False    False
# 2  False      False      False     True    False    False     True    False
# 3  False      False      False     True    False    False     True    False
# 4  False      False      False    False     True     True    False     True
#
#    6:30:00  7:30:00  8:30:00  9:30:00  10:30:00  11:30:00  12:30:00
# 0    False    False    False    False     False     False     False
# 1    False    False    False    False     False     False     False
# 2    False     True     True    False     False     False     False
# 3    False     True     True    False     False     False     False
# 4    False    False    False    False     False     False     False

# %%
pfizer_df.isnull().head()
# Out:
#     Date  Drug_Name  Parameter  1:30:00  2:30:00  3:30:00  4:30:00  5:30:00  \
# 0  False      False      False    False    False     True    False    False
# 1  False      False      False    False    False     True    False    False
# 2  False      False      False     True    False    False     True    False
# 3  False      False      False     True    False    False     True    False
# 4  False      False      False    False     True     True    False     True
#
#    6:30:00  7:30:00  8:30:00  9:30:00  10:30:00  11:30:00  12:30:00
# 0    False    False    False    False     False     False     False
# 1    False    False    False    False     False     False     False
# 2    False     True     True    False     False     False     False
# 3    False     True     True    False     False     False     False
# 4    False    False    False    False     False     False     False

# %%
pfizer_df.dropna()
# Out:
#           Date               Drug_Name    Parameter  1:30:00  2:30:00  \
# 14  17-10-2020     docetaxel injection  Temperature     12.0     13.0
# 15  17-10-2020     docetaxel injection     Pressure     20.0     22.0
# 16  17-10-2020  ketamine hydrochloride  Temperature     13.0     14.0
# 17  17-10-2020  ketamine hydrochloride     Pressure      8.0      9.0
#
#     3:30:00  4:30:00  5:30:00  6:30:00  7:30:00  8:30:00  9:30:00  10:30:00  \
# 14     14.0     15.0     16.0       17     18.0     19.0     20.0        21
# 15     22.0     22.0     22.0       23     25.0     26.0     27.0        28
# 16     15.0     16.0     17.0       18     19.0     20.0     21.0        22
# 17     10.0     11.0     11.0       12     12.0     11.0     12.0        13
#
#     11:30:00  12:30:00
# 14      22.0        23
# 15      29.0        28
# 16      23.0        24
# 17      14.0        15

# %%
pfizer_df.fillna(0,inplace=True)

# %%
pfizer_df
# Out:
#           Date                Drug_Name    Parameter  1:30:00  2:30:00  \
# 0   15-10-2020  diltiazem hydrochloride  Temperature     23.0     22.0
# 1   15-10-2020  diltiazem hydrochloride     Pressure     12.0     13.0
# 2   15-10-2020      docetaxel injection  Temperature      0.0     17.0
# 3   15-10-2020      docetaxel injection     Pressure      0.0     22.0
# 4   15-10-2020   ketamine hydrochloride  Temperature     24.0      0.0
# 5   15-10-2020   ketamine hydrochloride     Pressure      8.0      0.0
# 6   16-10-2020  diltiazem hydrochloride  Temperature     34.0     35.0
# 7   16-10-2020  diltiazem hydrochloride     Pressure     18.0     19.0
# 8   16-10-2020      docetaxel injection  Temperature     46.0     47.0
# 9   16-10-2020      docetaxel injection     Pressure     23.0     24.0
# 10  16-10-2020   ketamine hydrochloride  Temperature      8.0      9.0
# 11  16-10-2020   ketamine hydrochloride     Pressure     12.0     12.0
# ...

# %%
pd.Series([1,2,3,None])
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    NaN
# dtype: float64

# %%
pd.Series([1,2,3,np.nan])
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    NaN
# dtype: float64

# %%
pd.Series([1,2,3,np.nan,None])
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    NaN
# 4    NaN
# dtype: float64

# %%
pd.Series([1,2,3.0,np.nan,None])
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    NaN
# 4    NaN
# dtype: float64

# %%
pd.Series([1,2,"a",np.nan,None]).fillna(0)
# Out:
# 0    1
# 1    2
# 2    a
# 3    0
# 4    0
# dtype: object

# %%
import pandas as pd

df = pd.DataFrame({
  "Accessories": ["Laptop", "Laptop", "Ipad", "Ipad", "Tablet", "Laptop"],
  "customer": ["Andrew", "Andrew", "Tom", "Andrew", "Tobey", "Peter"],
  "quantity": [1, 2, 2, 3, 1, 2],
})

# %%
df
# Out:
#   Accessories customer  quantity
# 0      Laptop   Andrew         1
# 1      Laptop   Andrew         2
# 2        Ipad      Tom         2
# 3        Ipad   Andrew         3
# 4      Tablet    Tobey         1
# 5      Laptop    Peter         2

# %%
df.pivot(index="Accessories", columns="customer", values="quantity")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 df.pivot(index="Accessories", columns="customer", values="quantity")
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:9025, in DataFrame.pivot(self, columns, index, values)
#    9018 @Substitution("")
#    9019 @Appender(_shared_docs["pivot"])
#    9020 def pivot(
#    9021     self, *, columns, index=lib.no_default, values=lib.no_default
#    9022 ) -> DataFrame:
#    9023     from pandas.core.reshape.pivot import pivot
# -> 9025     return pivot(self, index=index, columns=columns, values=values)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/reshape/pivot.py:553, in pivot(data, columns, index, values)
#     549         indexed = data._constructor_sliced(data[values]._values, index=multiindex)
# ...

# %%
df.groupby(['Accessories', 'customer']).quantity.sum()
# Out:
# Accessories  customer
# Ipad         Andrew      3
#              Tom         2
# Laptop       Andrew      3
#              Peter       2
# Tablet       Tobey       1
# Name: quantity, dtype: int64

# %%
df.groupby(['Accessories', 'customer']).sum()
# Out:
#                       quantity
# Accessories customer
# Ipad        Andrew           3
#             Tom              2
# Laptop      Andrew           3
#             Peter            2
# Tablet      Tobey            1

# %%
df1=pd.read_csv('/home/thivakaranb/Downloads/sales.csv')

# %%
df1
# Out:
#         Invoice StockCode                          Description  Quantity  \
# 0        489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1        489434    79323P                   PINK CHERRY LIGHTS        12
# 2        489434    79323W                  WHITE CHERRY LIGHTS        12
# 3        489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4        489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...         ...       ...                                  ...       ...
# 1067366  581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 1067367  581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 1067368  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 1067369  581587     22138        BAKING SET 9 PIECE RETROSPOT          3
# 1067370  581587      POST                              POSTAGE         1
#
#                  InvoiceDate  Price  Customer ID         Country
# ...

# %%
df1['Sales'] = df1['Quantity'] * df1['Price']

# %%
df1
# Out:
#         Invoice StockCode                          Description  Quantity  \
# 0        489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1        489434    79323P                   PINK CHERRY LIGHTS        12
# 2        489434    79323W                  WHITE CHERRY LIGHTS        12
# 3        489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4        489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...         ...       ...                                  ...       ...
# 1067366  581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 1067367  581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 1067368  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 1067369  581587     22138        BAKING SET 9 PIECE RETROSPOT          3
# 1067370  581587      POST                              POSTAGE         1
#
#                  InvoiceDate  Price  Customer ID         Country   Sales
# ...

# %%
df1['InvoiceDate'] = pd.to_datetime(df1['InvoiceDate'])

# %%
df1.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#           InvoiceDate  Price  Customer ID         Country  Sales
# 0 2009-12-01 07:45:00   6.95      13085.0  United Kingdom   83.4
# 1 2009-12-01 07:45:00   6.75      13085.0  United Kingdom   81.0
# 2 2009-12-01 07:45:00   6.75      13085.0  United Kingdom   81.0
# 3 2009-12-01 07:45:00   2.10      13085.0  United Kingdom  100.8
# 4 2009-12-01 07:45:00   1.25      13085.0  United Kingdom   30.0

# %%
df1['Date'] = df1['InvoiceDate'].dt.date

# %%
df1.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#           InvoiceDate  Price  Customer ID         Country  Sales        Date
# 0 2009-12-01 07:45:00   6.95      13085.0  United Kingdom   83.4  2009-12-01
# 1 2009-12-01 07:45:00   6.75      13085.0  United Kingdom   81.0  2009-12-01
# 2 2009-12-01 07:45:00   6.75      13085.0  United Kingdom   81.0  2009-12-01
# 3 2009-12-01 07:45:00   2.10      13085.0  United Kingdom  100.8  2009-12-01
# 4 2009-12-01 07:45:00   1.25      13085.0  United Kingdom   30.0  2009-12-01

# %%
df_france = df1.loc[df1['Country'] == 'France']

# %%
df_france
# Out:
#         Invoice StockCode                        Description  Quantity  \
# 71       489439     22065     CHRISTMAS PUDDING TRINKET POT         12
# 72       489439     22138      BAKING SET 9 PIECE RETROSPOT          9
# 73       489439     22139  RETRO SPOT TEA SET CERAMIC 11 PC          9
# 74       489439     22352   LUNCHBOX WITH CUTLERY RETROSPOT         12
# 75       489439    85014A   BLACK/BLUE DOTS RUFFLED UMBRELLA         3
# ...         ...       ...                                ...       ...
# 1067366  581587     22899       CHILDREN'S APRON DOLLY GIRL          6
# 1067367  581587     23254      CHILDRENS CUTLERY DOLLY GIRL          4
# 1067368  581587     23255    CHILDRENS CUTLERY CIRCUS PARADE         4
# 1067369  581587     22138      BAKING SET 9 PIECE RETROSPOT          3
# 1067370  581587      POST                            POSTAGE         1
#
#                 InvoiceDate  Price  Customer ID Country  Sales        Date
# ...

# %%
france_sales_df = df_france.groupby('Date')['Sales'].sum().to_frame()

# %%
france_sales_df.sort_values('Sales',ascending=False)
# Out:
#                Sales
# Date
# 2010-08-09  12726.01
# 2011-10-28   8990.46
# 2010-05-06   8490.90
# 2011-03-31   5593.59
# 2010-11-19   5084.89
# ...              ...
# 2009-12-10   -118.90
# 2009-12-03   -143.90
# 2010-05-28   -364.80
# 2010-08-05   -421.40
# 2010-09-28 -11880.84
#
# [372 rows x 1 columns]

# %%
df1
# Out:
#         Invoice StockCode                          Description  Quantity  \
# 0        489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1        489434    79323P                   PINK CHERRY LIGHTS        12
# 2        489434    79323W                  WHITE CHERRY LIGHTS        12
# 3        489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4        489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...         ...       ...                                  ...       ...
# 1067366  581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 1067367  581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 1067368  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 1067369  581587     22138        BAKING SET 9 PIECE RETROSPOT          3
# 1067370  581587      POST                              POSTAGE         1
#
#                 InvoiceDate  Price  Customer ID         Country   Sales  \
# ...

# %%
df1.loc[df1['Date'] == pd.Timestamp('2011-06-22')]
# Out:
# Empty DataFrame
# Columns: [Invoice, StockCode, Description, Quantity, InvoiceDate, Price, Customer ID, Country, Sales, Date]
# Index: []

# %%
df1[df1['Date']== pd.Timestamp('2011-06-22')]
# Out:
# Empty DataFrame
# Columns: [Invoice, StockCode, Description, Quantity, InvoiceDate, Price, Customer ID, Country, Sales, Date]
# Index: []

# %%
df2 = pd.read_csv("/home/thivakaranb/Downloads/sales (3).csv")

# %%
df2
# Out:
#         Invoice StockCode                          Description  Quantity  \
# 0        489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1        489434    79323P                   PINK CHERRY LIGHTS        12
# 2        489434    79323W                  WHITE CHERRY LIGHTS        12
# 3        489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4        489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...         ...       ...                                  ...       ...
# 1067366  581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 1067367  581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 1067368  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 1067369  581587     22138        BAKING SET 9 PIECE RETROSPOT          3
# 1067370  581587      POST                              POSTAGE         1
#
#                  InvoiceDate  Price  Customer ID         Country
# ...

# %%
df2['Date'] =pd.to_datetime( df2['InvoiceDate']).dt.date

# %%
df2
# Out:
#         Invoice StockCode                          Description  Quantity  \
# 0        489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1        489434    79323P                   PINK CHERRY LIGHTS        12
# 2        489434    79323W                  WHITE CHERRY LIGHTS        12
# 3        489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4        489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...         ...       ...                                  ...       ...
# 1067366  581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 1067367  581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 1067368  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 1067369  581587     22138        BAKING SET 9 PIECE RETROSPOT          3
# 1067370  581587      POST                              POSTAGE         1
#
#                  InvoiceDate  Price  Customer ID         Country        Date
# ...

# %%
df2[df2['Date']==pd.Timestamp('2011-06-22')]
# Out:
# Empty DataFrame
# Columns: [Invoice, StockCode, Description, Quantity, InvoiceDate, Price, Customer ID, Country, Date]
# Index: []

# %%
df2[pd.to_datetime(df2['Date']).dt.strftime("%Y-%m-%d")=='2011-06-22']['Invoice'].nunique()
# Out:
# 68

# %%
df2[pd.to_datetime(df2['Date']).dt.strftime("%Y-%m-%d")=='2011-06-22']['Customer ID'].nunique()
# Out:
# 57

# %%
import pandas as pd
df = pd.DataFrame({'City\tState': ["Kolkata\tWest Bengal", "Chennai\tTamil Nadu", "Hyderabad\tTelengana", "Bangalore\tKarnataka"]})

# %%
df
# Out:
#             City\tState
# 0  Kolkata\tWest Bengal
# 1   Chennai\tTamil Nadu
# 2  Hyderabad\tTelengana
# 3  Bangalore\tKarnataka

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
pd.DataFrame(df['City\tState'].str.split('\t'),columns=['City','State'])
# Out:
# Empty DataFrame
# Columns: [City, State]
# Index: []

# %%
pd.DataFrame(df['City\tState'].str.split('\t'))
# Out:
#               City\tState
# 0  [Kolkata, West Bengal]
# 1   [Chennai, Tamil Nadu]
# 2  [Hyderabad, Telengana]
# 3  [Bangalore, Karnataka]

# %%
df.isna().sum().sum()
# Out:
# 0

# %%
pfizer_df
# Out:
#           Date                Drug_Name    Parameter  1:30:00  2:30:00  \
# 0   15-10-2020  diltiazem hydrochloride  Temperature     23.0     22.0
# 1   15-10-2020  diltiazem hydrochloride     Pressure     12.0     13.0
# 2   15-10-2020      docetaxel injection  Temperature      0.0     17.0
# 3   15-10-2020      docetaxel injection     Pressure      0.0     22.0
# 4   15-10-2020   ketamine hydrochloride  Temperature     24.0      0.0
# 5   15-10-2020   ketamine hydrochloride     Pressure      8.0      0.0
# 6   16-10-2020  diltiazem hydrochloride  Temperature     34.0     35.0
# 7   16-10-2020  diltiazem hydrochloride     Pressure     18.0     19.0
# 8   16-10-2020      docetaxel injection  Temperature     46.0     47.0
# 9   16-10-2020      docetaxel injection     Pressure     23.0     24.0
# 10  16-10-2020   ketamine hydrochloride  Temperature      8.0      9.0
# 11  16-10-2020   ketamine hydrochloride     Pressure     12.0     12.0
# ...

# %%
pfizer_df.isna().sum()
# Out:
# Date         0
# Drug_Name    0
# Parameter    0
# 1:30:00      2
# 2:30:00      2
# 3:30:00      6
# 4:30:00      4
# 5:30:00      2
# 6:30:00      0
# 7:30:00      2
# 8:30:00      4
# 9:30:00      2
# 10:30:00     0
# 11:30:00     2
# 12:30:00     0
# dtype: int64

# %%
pfizer_df.isna().sum().sum()
# Out:
# 26

# %%
pfizer_df.loc[[3]].isna()
# Out:
#     Date  Drug_Name  Parameter  1:30:00  2:30:00  3:30:00  4:30:00  5:30:00  \
# 3  False      False      False     True    False    False     True    False
#
#    6:30:00  7:30:00  8:30:00  9:30:00  10:30:00  11:30:00  12:30:00
# 3    False     True     True    False     False     False     False

# %%
pfizer_df.loc[3].isna()
# Out:
# Date         False
# Drug_Name    False
# Parameter    False
# 1:30:00       True
# 2:30:00      False
# 3:30:00      False
# 4:30:00       True
# 5:30:00      False
# 6:30:00      False
# 7:30:00       True
# 8:30:00       True
# 9:30:00      False
# 10:30:00     False
# 11:30:00     False
# 12:30:00     False
# Name: 3, dtype: bool
